# %% [markdown]
# # Top-3 Locked Uplift Config
#
# This notebook runs the fixed CatBoost Hurdle T-learner configuration from `top20_selected_configs.csv` without hyperparameter search. The main output is `predictions.csv`.

# %%
# %run uplift_top3_locked_config.py
